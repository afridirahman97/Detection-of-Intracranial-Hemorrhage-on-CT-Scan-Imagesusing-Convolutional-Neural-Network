# %%
# Necessary Dependencies
import numpy as np 
import pandas as pd 
# !pip install utils
from utils import *
from glob import glob
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from itertools import chain
from datetime import datetime
import statistics
from tqdm import tqdm
import tensorflow as tf
# DenseNet Dependencies
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.activations import sigmoid
from tensorflow.keras.layers import Dense,Conv2D, Flatten, Dropout, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.metrics import Accuracy, Precision, Recall, AUC, BinaryAccuracy, FalsePositives, FalseNegatives, TruePositives, TrueNegatives
from keras import regularizers
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.applications import DenseNet121, DenseNet169, DenseNet201, VGG16, ResNet50, InceptionResNetV2, InceptionV3
from keras import backend as K
from tensorflow.keras import Sequential
import keras 
import matplotlib
from sklearn.metrics import roc_curve, auc, roc_auc_score
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler
from sklearn.metrics import roc_curve, auc
print('Started')
# Out:
# Collecting utils
#   Downloading utils-1.0.1-py2.py3-none-any.whl (21 kB)
# Installing collected packages: utils
# Successfully installed utils-1.0.1
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Started

# %%
print('---Train Images-----')

path, dirs, files = next(os.walk("../input/intracranial-brain-hemorrhage-ct-images/intracranial brain hemorrhage dataset/Original/Train/Hemorrhage/hemorrhage_images"))
file_count = len(files)
print('Hemorrhage:',file_count)
path, dirs, files = next(os.walk("../input/intracranial-brain-hemorrhage-ct-images/intracranial brain hemorrhage dataset/Original/Train/Normal/normal_images"))
file_count = len(files)
print('Normal:',file_count)
# Out:
# ---Train Images-----
# Hemorrhage: 825
# Normal: 1426

# %%
print('---Test Images-----')

path, dirs, files = next(os.walk("../input/intracranial-brain-hemorrhage-ct-images/intracranial brain hemorrhage dataset/Original/Test/Hemorrhage/hemorrhage_images"))
file_count = len(files)
print('Hemorrhage:',file_count)
path, dirs, files = next(os.walk("../input/intracranial-brain-hemorrhage-ct-images/intracranial brain hemorrhage dataset/Original/Test/Normal/normal_images"))
file_count = len(files)
print('Normal:',file_count)
# Out:
# ---Test Images-----
# Hemorrhage: 125
# Normal: 125

# %%
image_size = (224, 224)
batch_size = 32

train_df = tf.keras.preprocessing.image_dataset_from_directory(
    "../input/intracranial-brain-hemorrhage-ct-images/intracranial brain hemorrhage dataset/Original/Train",
    validation_split=0.20,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val_df = tf.keras.preprocessing.image_dataset_from_directory(
    "../input/intracranial-brain-hemorrhage-ct-images/intracranial brain hemorrhage dataset/Original/Train",
    validation_split=0.2,
    subset="validation",
    seed=333,
    image_size=image_size,
    batch_size=batch_size,
)
test_df = tf.keras.preprocessing.image_dataset_from_directory(
    "../input/intracranial-brain-hemorrhage-ct-images/intracranial brain hemorrhage dataset/Original/Test",
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 2251 files belonging to 2 classes.
# Using 1801 files for training.
# Found 2251 files belonging to 2 classes.
# Using 450 files for validation.
# Found 250 files belonging to 2 classes.

# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
data_augmentation = keras.Sequential(
    [
        layers.experimental.preprocessing.RandomFlip("horizontal"),
        layers.experimental.preprocessing.RandomRotation(0.1),
        layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=None, fill_mode='reflect',
        interpolation='bilinear', seed=None, fill_value=0.0),
                layers.experimental.preprocessing.RandomCrop(height= 224, width = 224, seed=None),
    ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_df.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
train_df = train_df.prefetch(buffer_size=32)
val_df = val_df.prefetch(buffer_size=32)

# %%
# Hyperparameters
IMG_IND=224
IMG_SHAPE = (IMG_IND,IMG_IND,3)
LOSS = BinaryCrossentropy()
OPTIMIZER =Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
#OPTIMIZER =RMSprop(learning_rate=0.001)
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='BinaryAccuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
]

IMG_SIZE = (224, 224)
SEED = 2
BATCH_SIZE = 32

# %%
def get_callbacks(model_name):
    callbacks =[]
    tensor_board = tf.keras.callbacks.TensorBoard(log_dir='./logs', histogram_freq=0)
    callbacks.append(tensor_board)
    checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=f'model.{model_name}.h5', verbose=1, monitor='val_loss',mode='min',save_best_only=True)
    callbacks.append(checkpoint)
    anne = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=2, min_lr=0.0001,min_delta=0.00001,mode='auto') 
    callbacks.append(anne)
    return callbacks

# %%
base_model = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,include_top=False,weights='imagenet')
base_model.trainable = True
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(0.6)(x)  # Regularize with dropout
output = keras.layers.Dense(1)(x)

#adding regularization 



for layer in base_model.layers:
    layer.kernel_regularizer = tf.keras.regularizers.l1_l2(0.000001)
#    for attr in ['kernel_regularizer']:
#        if hasattr(layer, attr):
#          setattr(layer, attr, regularizer)


    
predictions = Dense(1, activation='sigmoid',name='Final')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(loss ='binary_crossentropy',optimizer=OPTIMIZER,metrics=METRICS)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 2s 0us/step

# %%
callbacks = get_callbacks('VGG16')
history_resnet50 = model.fit( train_df,epochs=20,
                    validation_data= val_df,
                    callbacks=[callbacks])
# Out:
# Epoch 1/20
# 57/57 [==============================] - 32s 316ms/step - loss: 4.4137 - tp: 472.9828 - fp: 282.6034 - tn: 63.3621 - fn: 123.7069 - BinaryAccuracy: 0.5563 - precision: 0.6259 - recall: 0.7490 - auc: 0.4869 - val_loss: 0.6644 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.5458
#
# Epoch 00001: val_loss improved from inf to 0.66442, saving model to model.VGG16.h5
# Epoch 2/20
# 57/57 [==============================] - 14s 238ms/step - loss: 0.6909 - tp: 590.0000 - fp: 338.7586 - tn: 5.0517 - fn: 8.8448 - BinaryAccuracy: 0.6346 - precision: 0.6386 - recall: 0.9851 - auc: 0.4773 - val_loss: 0.6910 - val_tp: 262.0000 - val_fp: 151.0000 - val_tn: 22.0000 - val_fn: 15.0000 - val_BinaryAccuracy: 0.6311 - val_precision: 0.6344 - val_recall: 0.9458 - val_auc: 0.5584
#
# Epoch 00002: val_loss did not improve from 0.66442
# Epoch 3/20
# 57/57 [==============================] - 14s 241ms/step - loss: 0.6905 - tp: 522.6724 - fp: 300.6552 - tn: 41.9655 - fn: 77.3621 - BinaryAccuracy: 0.5958 - precision: 0.6326 - recall: 0.8669 - auc: 0.4987 - val_loss: 0.6669 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.5461
#
# Epoch 00003: val_loss did not improve from 0.66442
# Epoch 4/20
# 57/57 [==============================] - 14s 237ms/step - loss: 0.6722 - tp: 545.1897 - fp: 308.4483 - tn: 36.7931 - fn: 52.2241 - BinaryAccuracy: 0.6199 - precision: 0.6397 - recall: 0.9177 - auc: 0.5024 - val_loss: 0.6678 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.5478
#
# Epoch 00004: val_loss did not improve from 0.66442
# Epoch 5/20
# 57/57 [==============================] - 14s 239ms/step - loss: 0.6727 - tp: 545.1552 - fp: 312.0000 - tn: 34.4138 - fn: 51.0862 - BinaryAccuracy: 0.6099 - precision: 0.6347 - recall: 0.9001 - auc: 0.5106 - val_loss: 0.6591 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.7542
#
# Epoch 00005: val_loss improved from 0.66442 to 0.65907, saving model to model.VGG16.h5
# Epoch 6/20
# 57/57 [==============================] - 14s 241ms/step - loss: 0.6637 - tp: 570.8448 - fp: 325.2759 - tn: 20.4138 - fn: 26.1207 - BinaryAccuracy: 0.6253 - precision: 0.6335 - recall: 0.9621 - auc: 0.5274 - val_loss: 0.6559 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.7471
#
# Epoch 00006: val_loss improved from 0.65907 to 0.65593, saving model to model.VGG16.h5
# Epoch 7/20
# 57/57 [==============================] - 14s 238ms/step - loss: 0.6675 - tp: 562.7586 - fp: 314.5690 - tn: 27.4483 - fn: 37.8793 - BinaryAccuracy: 0.6257 - precision: 0.6414 - recall: 0.9360 - auc: 0.5316 - val_loss: 0.6794 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.5772
#
# Epoch 00007: val_loss did not improve from 0.65593
# Epoch 8/20
# 57/57 [==============================] - 14s 240ms/step - loss: 0.6855 - tp: 590.0690 - fp: 339.4138 - tn: 5.0172 - fn: 8.1552 - BinaryAccuracy: 0.6275 - precision: 0.6308 - recall: 0.9876 - auc: 0.5020 - val_loss: 0.6578 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.6283
#
# Epoch 00008: val_loss did not improve from 0.65593
# Epoch 9/20
# 57/57 [==============================] - 14s 235ms/step - loss: 0.6720 - tp: 593.7931 - fp: 344.5345 - tn: 3.0517 - fn: 1.2759 - BinaryAccuracy: 0.6326 - precision: 0.6322 - recall: 0.9982 - auc: 0.4690 - val_loss: 0.6683 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.4480
#
# Epoch 00009: val_loss did not improve from 0.65593
# Epoch 10/20
# 57/57 [==============================] - 14s 237ms/step - loss: 0.6696 - tp: 595.7241 - fp: 346.9310 - tn: 0.0000e+00 - fn: 0.0000e+00 - BinaryAccuracy: 0.6268 - precision: 0.6268 - recall: 1.0000 - auc: 0.4667 - val_loss: 0.6453 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.6180
#
# Epoch 00010: val_loss improved from 0.65593 to 0.64532, saving model to model.VGG16.h5
# Epoch 11/20
# 57/57 [==============================] - 14s 242ms/step - loss: 0.6530 - tp: 587.1379 - fp: 327.5000 - tn: 14.3448 - fn: 13.6724 - BinaryAccuracy: 0.6440 - precision: 0.6460 - recall: 0.9862 - auc: 0.5498 - val_loss: 0.6727 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.5936
#
# Epoch 00011: val_loss did not improve from 0.64532
# Epoch 12/20
# 57/57 [==============================] - 14s 241ms/step - loss: 0.6713 - tp: 601.2414 - fp: 341.4138 - tn: 0.0000e+00 - fn: 0.0000e+00 - BinaryAccuracy: 0.6428 - precision: 0.6428 - recall: 1.0000 - auc: 0.4924 - val_loss: 0.6604 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.5623
#
# Epoch 00012: val_loss did not improve from 0.64532
# Epoch 13/20
# 57/57 [==============================] - 14s 236ms/step - loss: 0.6622 - tp: 596.2759 - fp: 346.3793 - tn: 0.0000e+00 - fn: 0.0000e+00 - BinaryAccuracy: 0.6289 - precision: 0.6289 - recall: 1.0000 - auc: 0.5302 - val_loss: 0.6618 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.6051
#
# Epoch 00013: val_loss did not improve from 0.64532
# Epoch 14/20
# 57/57 [==============================] - 14s 239ms/step - loss: 0.6590 - tp: 599.8621 - fp: 342.7931 - tn: 0.0000e+00 - fn: 0.0000e+00 - BinaryAccuracy: 0.6333 - precision: 0.6333 - recall: 1.0000 - auc: 0.5139 - val_loss: 0.6591 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.6103
#
# Epoch 00014: val_loss did not improve from 0.64532
# Epoch 15/20
# 57/57 [==============================] - 15s 242ms/step - loss: 0.6697 - tp: 592.6897 - fp: 342.6207 - tn: 2.7931 - fn: 4.5517 - BinaryAccuracy: 0.6210 - precision: 0.6233 - recall: 0.9899 - auc: 0.4973 - val_loss: 0.6656 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.5453
#
# Epoch 00015: val_loss did not improve from 0.64532
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 16/20
# 57/57 [==============================] - 14s 238ms/step - loss: 0.6557 - tp: 600.7241 - fp: 341.9310 - tn: 0.0000e+00 - fn: 0.0000e+00 - BinaryAccuracy: 0.6413 - precision: 0.6413 - recall: 1.0000 - auc: 0.5062 - val_loss: 0.6659 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.5418
#
# Epoch 00016: val_loss did not improve from 0.64532
# Epoch 17/20
# 57/57 [==============================] - 15s 242ms/step - loss: 0.6552 - tp: 599.1034 - fp: 343.5517 - tn: 0.0000e+00 - fn: 0.0000e+00 - BinaryAccuracy: 0.6404 - precision: 0.6404 - recall: 1.0000 - auc: 0.5095 - val_loss: 0.6655 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.5553
#
# Epoch 00017: val_loss did not improve from 0.64532
# Epoch 18/20
# 57/57 [==============================] - 14s 239ms/step - loss: 0.6601 - tp: 597.7241 - fp: 344.9310 - tn: 0.0000e+00 - fn: 0.0000e+00 - BinaryAccuracy: 0.6281 - precision: 0.6281 - recall: 1.0000 - auc: 0.5160 - val_loss: 0.6647 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.5905
#
# Epoch 00018: val_loss did not improve from 0.64532
# Epoch 19/20
# 57/57 [==============================] - 14s 241ms/step - loss: 0.6558 - tp: 598.5690 - fp: 344.0862 - tn: 0.0000e+00 - fn: 0.0000e+00 - BinaryAccuracy: 0.6372 - precision: 0.6372 - recall: 1.0000 - auc: 0.5178 - val_loss: 0.6646 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.5895
#
# Epoch 00019: val_loss did not improve from 0.64532
# Epoch 20/20
# 57/57 [==============================] - 14s 239ms/step - loss: 0.6569 - tp: 599.6552 - fp: 343.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - BinaryAccuracy: 0.6368 - precision: 0.6368 - recall: 1.0000 - auc: 0.5072 - val_loss: 0.6640 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.5970
#
# Epoch 00020: val_loss did not improve from 0.64532
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0001.

# %%
results_resnet50 = model.evaluate(test_df, steps=len(test_df), verbose=1)
# Out:
# 8/8 [==============================] - 4s 418ms/step - loss: 0.7275 - tp: 125.0000 - fp: 125.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - BinaryAccuracy: 0.5000 - precision: 0.5000 - recall: 1.0000 - auc: 0.4774

# %%
print('Vgg16-Adam:')
print('---------------')
print("Binary Accuracy: ",(results_resnet50[5]))
print("Precision: ",(results_resnet50[6]))
print("Recall: ",(results_resnet50[7]))
print("AUC: ",(results_resnet50[8]))
print("F1 Score: ",(2*((results_resnet50[6]*results_resnet50[7])/((results_resnet50[6]+results_resnet50[7])))))
# Out:
# Vgg16-Adam:
# ---------------
# Binary Accuracy:  0.5
# Precision:  0.5
# Recall:  1.0
# AUC:  0.4773760437965393
# F1 Score:  0.6666666666666666

# %%
import numpy as np


def plot_confusion_matrix(cm,
                          target_names_y,
                          target_names_x,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names_x is not None:
        tick_marks = np.arange(len(target_names_x))
        plt.xticks(tick_marks, target_names_x, rotation=45)
        plt.yticks(tick_marks, target_names_y)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
   # plt.ylabel('True label')
   
    plt.show()

# %%
plot_confusion_matrix(cm           = np.array([[ 121.0000,  115.0000],
                                              [  10.0000,   4.0000],
                                              ]), 
                      normalize    = False,
                      target_names_x = ['Positive', 'Negative'],
                      target_names_y = ['True', 'False'],
                      title        = "Confusion Matrix of ResNet50")
