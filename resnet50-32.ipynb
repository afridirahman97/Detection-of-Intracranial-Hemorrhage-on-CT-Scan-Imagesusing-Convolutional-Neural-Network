# %%
# Necessary Dependencies
import numpy as np 
import pandas as pd 
# !pip install utils
from utils import *
from glob import glob
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from itertools import chain
from datetime import datetime
import statistics
from tqdm import tqdm
import tensorflow as tf
# DenseNet Dependencies
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.activations import sigmoid
from tensorflow.keras.layers import Dense,Conv2D, Flatten, Dropout, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.metrics import Accuracy, Precision, Recall, AUC, BinaryAccuracy, FalsePositives, FalseNegatives, TruePositives, TrueNegatives
from keras import regularizers
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.applications import DenseNet121, DenseNet169, DenseNet201, VGG16, ResNet50, InceptionResNetV2, InceptionV3
from keras import backend as K
from tensorflow.keras import Sequential
import keras 
import matplotlib
from sklearn.metrics import roc_curve, auc, roc_auc_score
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler
from sklearn.metrics import roc_curve, auc
print('Started')
# Out:
# Collecting utils
#   Downloading utils-1.0.1-py2.py3-none-any.whl (21 kB)
# Installing collected packages: utils
# Successfully installed utils-1.0.1
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Started

# %%
print('---Train Images-----')

path, dirs, files = next(os.walk("../input/intracranial-brain-hemorrhage-ct-images/intracranial brain hemorrhage dataset/Original/Train/Hemorrhage/hemorrhage_images"))
file_count = len(files)
print('Hemorrhage:',file_count)
path, dirs, files = next(os.walk("../input/intracranial-brain-hemorrhage-ct-images/intracranial brain hemorrhage dataset/Original/Train/Normal/normal_images"))
file_count = len(files)
print('Normal:',file_count)
# Out:
# ---Train Images-----
# Hemorrhage: 825
# Normal: 1426

# %%
print('---Test Images-----')

path, dirs, files = next(os.walk("../input/intracranial-brain-hemorrhage-ct-images/intracranial brain hemorrhage dataset/Original/Test/Hemorrhage/hemorrhage_images"))
file_count = len(files)
print('Hemorrhage:',file_count)
path, dirs, files = next(os.walk("../input/intracranial-brain-hemorrhage-ct-images/intracranial brain hemorrhage dataset/Original/Test/Normal/normal_images"))
file_count = len(files)
print('Normal:',file_count)
# Out:
# ---Test Images-----
# Hemorrhage: 125
# Normal: 125

# %%
image_size = (224, 224)
batch_size = 32

train_df = tf.keras.preprocessing.image_dataset_from_directory(
    "../input/intracranial-brain-hemorrhage-ct-images/intracranial brain hemorrhage dataset/Original/Train",
    validation_split=0.20,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val_df = tf.keras.preprocessing.image_dataset_from_directory(
    "../input/intracranial-brain-hemorrhage-ct-images/intracranial brain hemorrhage dataset/Original/Train",
    validation_split=0.2,
    subset="validation",
    seed=333,
    image_size=image_size,
    batch_size=batch_size,
)
test_df = tf.keras.preprocessing.image_dataset_from_directory(
    "../input/intracranial-brain-hemorrhage-ct-images/intracranial brain hemorrhage dataset/Original/Test",
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 2251 files belonging to 2 classes.
# Using 1801 files for training.
# Found 2251 files belonging to 2 classes.
# Using 450 files for validation.
# Found 250 files belonging to 2 classes.

# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
data_augmentation = keras.Sequential(
    [
        layers.experimental.preprocessing.RandomFlip("horizontal"),
        layers.experimental.preprocessing.RandomRotation(0.1),
        layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=None, fill_mode='reflect',
        interpolation='bilinear', seed=None, fill_value=0.0),
                layers.experimental.preprocessing.RandomCrop(height= 224, width = 224, seed=None),
    ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_df.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
train_df = train_df.prefetch(buffer_size=32)
val_df = val_df.prefetch(buffer_size=32)

# %%
# Hyperparameters
IMG_IND=224
IMG_SHAPE = (IMG_IND,IMG_IND,3)
LOSS = BinaryCrossentropy()
OPTIMIZER =Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
#OPTIMIZER =RMSprop(learning_rate=0.001)
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='BinaryAccuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
]

IMG_SIZE = (224, 224)
SEED = 2
BATCH_SIZE = 32

# %%
def get_callbacks(model_name):
    callbacks =[]
    tensor_board = tf.keras.callbacks.TensorBoard(log_dir='./logs', histogram_freq=0)
    callbacks.append(tensor_board)
    checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=f'model.{model_name}.h5', verbose=1, monitor='val_loss',mode='min',save_best_only=True)
    callbacks.append(checkpoint)
    anne = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=2, min_lr=0.0001,min_delta=0.00001,mode='auto') 
    callbacks.append(anne)
    return callbacks

# %%
base_model = tf.keras.applications.ResNet50(input_shape=IMG_SHAPE,include_top=False,weights='imagenet')
base_model.trainable = True
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(0.6)(x)  # Regularize with dropout
output = keras.layers.Dense(1)(x)

#adding regularization 



for layer in base_model.layers:
    layer.kernel_regularizer = tf.keras.regularizers.l1_l2(0.000001)
#    for attr in ['kernel_regularizer']:
#        if hasattr(layer, attr):
#          setattr(layer, attr, regularizer)


    
predictions = Dense(1, activation='sigmoid',name='Final')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(loss ='binary_crossentropy',optimizer=OPTIMIZER,metrics=METRICS)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step

# %%
callbacks = get_callbacks('ResNet50')
history_resnet50 = model.fit( train_df,epochs=20,
                    validation_data= val_df,
                    callbacks=[callbacks])
# Out:
# Epoch 1/20
# 57/57 [==============================] - 28s 263ms/step - loss: 0.8059 - tp: 467.3448 - fp: 170.8448 - tn: 175.1207 - fn: 129.3448 - BinaryAccuracy: 0.6583 - precision: 0.7171 - recall: 0.7646 - auc: 0.6489 - val_loss: 79.1087 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 173.0000 - val_fn: 277.0000 - val_BinaryAccuracy: 0.3844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5036
#
# Epoch 00001: val_loss improved from inf to 79.10867, saving model to model.ResNet50.h5
# Epoch 2/20
# 57/57 [==============================] - 12s 198ms/step - loss: 0.3644 - tp: 543.9483 - fp: 87.4828 - tn: 256.3276 - fn: 54.8966 - BinaryAccuracy: 0.8335 - precision: 0.8447 - recall: 0.9080 - auc: 0.9132 - val_loss: 4.8477 - val_tp: 60.0000 - val_fp: 0.0000e+00 - val_tn: 173.0000 - val_fn: 217.0000 - val_BinaryAccuracy: 0.5178 - val_precision: 1.0000 - val_recall: 0.2166 - val_auc: 0.7106
#
# Epoch 00002: val_loss improved from 79.10867 to 4.84773, saving model to model.ResNet50.h5
# Epoch 3/20
# 57/57 [==============================] - 12s 202ms/step - loss: 0.2144 - tp: 566.2069 - fp: 48.2759 - tn: 294.3448 - fn: 33.8276 - BinaryAccuracy: 0.9097 - precision: 0.9256 - recall: 0.9338 - auc: 0.9688 - val_loss: 1.6884 - val_tp: 214.0000 - val_fp: 11.0000 - val_tn: 162.0000 - val_fn: 63.0000 - val_BinaryAccuracy: 0.8356 - val_precision: 0.9511 - val_recall: 0.7726 - val_auc: 0.9093
#
# Epoch 00003: val_loss improved from 4.84773 to 1.68844, saving model to model.ResNet50.h5
# Epoch 4/20
# 57/57 [==============================] - 12s 201ms/step - loss: 0.1703 - tp: 577.4655 - fp: 30.8621 - tn: 314.3793 - fn: 19.9483 - BinaryAccuracy: 0.9382 - precision: 0.9425 - recall: 0.9614 - auc: 0.9780 - val_loss: 0.2432 - val_tp: 251.0000 - val_fp: 8.0000 - val_tn: 165.0000 - val_fn: 26.0000 - val_BinaryAccuracy: 0.9244 - val_precision: 0.9691 - val_recall: 0.9061 - val_auc: 0.9825
#
# Epoch 00004: val_loss improved from 1.68844 to 0.24319, saving model to model.ResNet50.h5
# Epoch 5/20
# 57/57 [==============================] - 12s 201ms/step - loss: 0.0564 - tp: 590.3448 - fp: 11.8621 - tn: 334.5517 - fn: 5.8966 - BinaryAccuracy: 0.9816 - precision: 0.9796 - recall: 0.9914 - auc: 0.9983 - val_loss: 2.7026 - val_tp: 76.0000 - val_fp: 0.0000e+00 - val_tn: 173.0000 - val_fn: 201.0000 - val_BinaryAccuracy: 0.5533 - val_precision: 1.0000 - val_recall: 0.2744 - val_auc: 0.8559
#
# Epoch 00005: val_loss did not improve from 0.24319
# Epoch 6/20
# 57/57 [==============================] - 12s 199ms/step - loss: 0.0412 - tp: 591.7586 - fp: 8.7759 - tn: 336.9138 - fn: 5.2069 - BinaryAccuracy: 0.9837 - precision: 0.9849 - recall: 0.9892 - auc: 0.9987 - val_loss: 1.0296 - val_tp: 197.0000 - val_fp: 1.0000 - val_tn: 172.0000 - val_fn: 80.0000 - val_BinaryAccuracy: 0.8200 - val_precision: 0.9949 - val_recall: 0.7112 - val_auc: 0.9316
#
# Epoch 00006: val_loss did not improve from 0.24319
# Epoch 7/20
# 57/57 [==============================] - 12s 199ms/step - loss: 0.0833 - tp: 586.6207 - fp: 14.9310 - tn: 327.0862 - fn: 14.0172 - BinaryAccuracy: 0.9696 - precision: 0.9772 - recall: 0.9751 - auc: 0.9944 - val_loss: 22.5140 - val_tp: 277.0000 - val_fp: 173.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.6156 - val_precision: 0.6156 - val_recall: 1.0000 - val_auc: 0.5000
#
# Epoch 00007: val_loss did not improve from 0.24319
# Epoch 8/20
# 57/57 [==============================] - 12s 198ms/step - loss: 0.0547 - tp: 590.3448 - fp: 8.7759 - tn: 335.6552 - fn: 7.8793 - BinaryAccuracy: 0.9843 - precision: 0.9883 - recall: 0.9870 - auc: 0.9980 - val_loss: 0.4665 - val_tp: 264.0000 - val_fp: 19.0000 - val_tn: 154.0000 - val_fn: 13.0000 - val_BinaryAccuracy: 0.9289 - val_precision: 0.9329 - val_recall: 0.9531 - val_auc: 0.9602
#
# Epoch 00008: val_loss did not improve from 0.24319
# Epoch 9/20
# 57/57 [==============================] - 13s 212ms/step - loss: 0.1597 - tp: 575.0172 - fp: 24.6552 - tn: 322.9310 - fn: 20.0517 - BinaryAccuracy: 0.9468 - precision: 0.9509 - recall: 0.9657 - auc: 0.9821 - val_loss: 0.2727 - val_tp: 277.0000 - val_fp: 22.0000 - val_tn: 151.0000 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.9511 - val_precision: 0.9264 - val_recall: 1.0000 - val_auc: 0.9696
#
# Epoch 00009: val_loss did not improve from 0.24319
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 10/20
# 57/57 [==============================] - 12s 196ms/step - loss: 0.0493 - tp: 595.1207 - fp: 13.5172 - tn: 333.4138 - fn: 0.6034 - BinaryAccuracy: 0.9825 - precision: 0.9736 - recall: 0.9992 - auc: 0.9976 - val_loss: 0.0188 - val_tp: 277.0000 - val_fp: 4.0000 - val_tn: 169.0000 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 0.9911 - val_precision: 0.9858 - val_recall: 1.0000 - val_auc: 1.0000
#
# Epoch 00010: val_loss improved from 0.24319 to 0.01884, saving model to model.ResNet50.h5
# Epoch 11/20
# 57/57 [==============================] - 12s 201ms/step - loss: 0.0157 - tp: 600.0172 - fp: 4.5690 - tn: 337.2759 - fn: 0.7931 - BinaryAccuracy: 0.9944 - precision: 0.9926 - recall: 0.9987 - auc: 1.0000 - val_loss: 0.0020 - val_tp: 277.0000 - val_fp: 0.0000e+00 - val_tn: 173.0000 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
#
# Epoch 00011: val_loss improved from 0.01884 to 0.00197, saving model to model.ResNet50.h5
# Epoch 12/20
# 57/57 [==============================] - 12s 197ms/step - loss: 0.0121 - tp: 601.2414 - fp: 2.8793 - tn: 338.5345 - fn: 0.0000e+00 - BinaryAccuracy: 0.9968 - precision: 0.9951 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0027 - val_tp: 277.0000 - val_fp: 0.0000e+00 - val_tn: 173.0000 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
#
# Epoch 00012: val_loss did not improve from 0.00197
# Epoch 13/20
# 57/57 [==============================] - 12s 203ms/step - loss: 0.0079 - tp: 596.2759 - fp: 0.9483 - tn: 345.4310 - fn: 0.0000e+00 - BinaryAccuracy: 0.9992 - precision: 0.9988 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0026 - val_tp: 277.0000 - val_fp: 0.0000e+00 - val_tn: 173.0000 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
#
# Epoch 00013: val_loss did not improve from 0.00197
# Epoch 14/20
# 57/57 [==============================] - 12s 201ms/step - loss: 0.0053 - tp: 599.8621 - fp: 0.4483 - tn: 342.3448 - fn: 0.0000e+00 - BinaryAccuracy: 0.9997 - precision: 0.9996 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0022 - val_tp: 277.0000 - val_fp: 0.0000e+00 - val_tn: 173.0000 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
#
# Epoch 00014: val_loss did not improve from 0.00197
# Epoch 15/20
# 57/57 [==============================] - 12s 199ms/step - loss: 0.0094 - tp: 597.2414 - fp: 0.5690 - tn: 344.8448 - fn: 0.0000e+00 - BinaryAccuracy: 0.9996 - precision: 0.9993 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0026 - val_tp: 277.0000 - val_fp: 0.0000e+00 - val_tn: 173.0000 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
#
# Epoch 00015: val_loss did not improve from 0.00197
# Epoch 16/20
# 57/57 [==============================] - 12s 198ms/step - loss: 0.0055 - tp: 600.7241 - fp: 0.6724 - tn: 341.2586 - fn: 0.0000e+00 - BinaryAccuracy: 0.9994 - precision: 0.9991 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0024 - val_tp: 277.0000 - val_fp: 0.0000e+00 - val_tn: 173.0000 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
#
# Epoch 00016: val_loss did not improve from 0.00197
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 17/20
# 57/57 [==============================] - 12s 198ms/step - loss: 0.0047 - tp: 598.9483 - fp: 0.6897 - tn: 342.8621 - fn: 0.1552 - BinaryAccuracy: 0.9993 - precision: 0.9990 - recall: 0.9999 - auc: 1.0000 - val_loss: 0.0025 - val_tp: 277.0000 - val_fp: 0.0000e+00 - val_tn: 173.0000 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
#
# Epoch 00017: val_loss did not improve from 0.00197
# Epoch 18/20
# 57/57 [==============================] - 12s 198ms/step - loss: 0.0056 - tp: 597.0517 - fp: 0.5862 - tn: 344.3448 - fn: 0.6724 - BinaryAccuracy: 0.9989 - precision: 0.9993 - recall: 0.9991 - auc: 1.0000 - val_loss: 0.0030 - val_tp: 277.0000 - val_fp: 0.0000e+00 - val_tn: 173.0000 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
#
# Epoch 00018: val_loss did not improve from 0.00197
# Epoch 19/20
# 57/57 [==============================] - 12s 201ms/step - loss: 0.0054 - tp: 598.5690 - fp: 0.5690 - tn: 343.5172 - fn: 0.0000e+00 - BinaryAccuracy: 0.9996 - precision: 0.9993 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0016 - val_tp: 277.0000 - val_fp: 0.0000e+00 - val_tn: 173.0000 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
#
# Epoch 00019: val_loss improved from 0.00197 to 0.00158, saving model to model.ResNet50.h5
# Epoch 20/20
# 57/57 [==============================] - 12s 198ms/step - loss: 0.0025 - tp: 599.6552 - fp: 0.0000e+00 - tn: 343.0000 - fn: 0.0000e+00 - BinaryAccuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0013 - val_tp: 277.0000 - val_fp: 0.0000e+00 - val_tn: 173.0000 - val_fn: 0.0000e+00 - val_BinaryAccuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
#
# Epoch 00020: val_loss improved from 0.00158 to 0.00130, saving model to model.ResNet50.h5

# %%
results_resnet50 = model.evaluate(test_df, steps=len(test_df), verbose=1)
# Out:
# 8/8 [==============================] - 2s 87ms/step - loss: 0.2665 - tp: 117.0000 - fp: 7.0000 - tn: 118.0000 - fn: 8.0000 - BinaryAccuracy: 0.9400 - precision: 0.9435 - recall: 0.9360 - auc: 0.9659

# %%
print('Resnet50-Adam:')
print('---------------')
print("Binary Accuracy: ",(results_resnet50[5]))
print("Precision: ",(results_resnet50[6]))
print("Recall: ",(results_resnet50[7]))
print("AUC: ",(results_resnet50[8]))
print("F1 Score: ",(2*((results_resnet50[6]*results_resnet50[7])/((results_resnet50[6]+results_resnet50[7])))))
# Out:
# Resnet50-Adam:
# ---------------
# Binary Accuracy:  0.9399999976158142
# Precision:  0.9435483813285828
# Recall:  0.9359999895095825
# AUC:  0.9658559560775757
# F1 Score:  0.9397590279961779

# %%
model.save('brain_stroke_detection_resnet50.h5')

import matplotlib.pyplot as plt

acc = history_resnet50.history['BinaryAccuracy']
val_acc = history_resnet50.history['val_BinaryAccuracy']
loss = history_resnet50.history['loss']
val_loss = history_resnet50.history['val_loss']

epochs = range(1, len(acc) + 1)

fig = plt.figure(figsize=(6,4))
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'g', label='Validation accuracy')
plt.title('Training and validation accuracy with ResNet50')
plt.legend()

plt.figure()

fig = plt.figure(figsize=(6,4))
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss with ResNet50')
plt.legend()

# %%
AUC = history_resnet50.history['auc']
val_AUC = history_resnet50.history['val_auc']

epochs = range(1, len(acc) + 1)

fig = plt.figure(figsize=(6,4))
plt.plot(epochs, AUC, 'g', label='AUC')
plt.plot(epochs, val_AUC, 'b', label='Val_AUC')
plt.xlabel('No.of epochs')
plt.ylabel('AUC')
plt.title('Training and validation AUC with ResNet50')
plt.legend()
plt.figure()

# %% [markdown]
# <a href="./brain_stroke_detection_resnet50.h5">Download h5-file ResNet50</a>

# %%
import numpy as np


def plot_confusion_matrix(cm,
                          target_names_y,
                          target_names_x,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names_x is not None:
        tick_marks = np.arange(len(target_names_x))
        plt.xticks(tick_marks, target_names_x, rotation=45)
        plt.yticks(tick_marks, target_names_y)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
   # plt.ylabel('True label')
   
    plt.show()

# %%
plot_confusion_matrix(cm           = np.array([[ 121.0000,  115.0000],
                                              [  10.0000,   4.0000],
                                              ]), 
                      normalize    = False,
                      target_names_x = ['Positive', 'Negative'],
                      target_names_y = ['True', 'False'],
                      title        = "Confusion Matrix of ResNet50")
